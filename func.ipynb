# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_excel("VentasTabla.xlsx")

# %%
df.tail()
# Out:
#         Fecha  AMERICANA  AMERICANA LIGTH  ANANA  BANANA SPLIT  \
# 69 2023-01-09      9.695            1.115  2.835         8.320
# 70 2023-01-16      2.125            3.480  6.425         3.605
# 71 2023-01-22     10.175            1.480  3.955         8.015
# 72 2023-01-30      5.785            2.800  8.450         2.960
# 73 2023-02-05     11.145            0.000  5.935         6.755
#
#     BANANITA DOLCA  CEREZA  CHEESSECAKE MARACUYA  CH AMARGO  CH BLANCO  ...  \
# 69           8.600   7.760                11.675      6.620      9.945  ...
# 70           4.825   4.340                 5.760      9.065      6.235  ...
# 71           3.645   9.035                 2.510      3.205      2.825  ...
# 72           7.465   6.240                 3.765      7.250      7.445  ...
# 73           3.370   2.670                 4.880     10.210      4.110  ...
#
#     SAMBAYON  TIRAMISU  TRAMONTANA  VAINILLA  VAINILLA NUTTY  CHOCOTORTA  \
# ...

# %%
def agrupar_mensual(data):
    df = data.copy()
    #df.set_index('Fecha')
    return df.groupby(pd.Grouper(key='Fecha', freq='M')).sum()
    
def venta_anual(df, helado):
    return df[helado].sum()

def venta_sort(data, fecha):
    df = data.set_index('Fecha')
    df = df.loc[fecha]
    return df.sort_values(ascending = False)

# %%
df
# Out:
#         Fecha  AMERICANA  AMERICANA LIGTH  ANANA  BANANA SPLIT  \
# 0  2021-10-29     13.955            3.320  5.185        12.655
# 1  2021-10-31     11.865            3.315  4.620        11.845
# 2  2021-11-04     11.440            3.315  4.235        11.280
# 3  2021-11-07      9.795            3.100  3.545        10.395
# 4  2021-11-11      9.670            3.075  8.700        10.180
# ..        ...        ...              ...    ...           ...
# 69 2023-01-09      9.695            1.115  2.835         8.320
# 70 2023-01-16      2.125            3.480  6.425         3.605
# 71 2023-01-22     10.175            1.480  3.955         8.015
# 72 2023-01-30      5.785            2.800  8.450         2.960
# 73 2023-02-05     11.145            0.000  5.935         6.755
#
#     BANANITA DOLCA  CEREZA  CHEESSECAKE MARACUYA  CH AMARGO  CH BLANCO  ...  \
# 0           12.850  12.840                 6.425     14.430      6.510  ...
# ...

# %%
j = venta_sort(df, '2023-02-05')
j
# Out:
# CH CHUII                17.245
# DL CHUII                16.430
# CH ROCHER               14.730
# FRUTOS DEL BOSQUE       14.420
# KINDER                  14.395
# LIMON                   13.730
# DL                      12.410
# VAINILLA                12.325
# TRAMONTANA              12.250
# CH CON ALMENDRAS        11.920
# AMERICANA               11.145
# CH AMARGO               10.210
# DL con NUEZ              9.365
# DL GRANIZADO             9.305
# MANTECOL                 9.240
# FLAN C DL                8.970
# CHOCOLATE                8.890
# CHOCOTORTA               8.665
# GRANIZADO                8.655
# PISTACHO                 8.430
# CHOCOLATE SHOT           8.410
# COOKIES                  8.215
# SAMBAYON                 8.140
# DL CON BROWNIES          8.015
# MENTA GRANIZADA          7.620
# MANDARINA                7.420
# VAINILLA NUTTY           6.970
# DURAZNO                  6.870
# FRAMBUESA                6.840
# BANANA SPLIT             6.755
# ...

# %%
sem = venta_sort(df, '2021-10-29')

# %%
sem
# Out:
# DL CHUII                19.710
# SAMBAYON                14.775
# CH AMARGO               14.430
# KINDER                  14.135
# VAINILLA NUTTY          14.020
# AMERICANA               13.955
# CH CHUII                13.935
# CH SUIZO                13.780
# DL GRANIZADO            13.725
# FLAN C DL               13.650
# CH CON ALMENDRAS        13.500
# VAINILLA                13.430
# MENTA GRANIZADA         13.420
# COOKIES                 13.385
# GRANIZADO               13.365
# DL CON BROWNIES         13.310
# MOUSE DE CH             13.190
# MANTECOL                13.180
# DL                      13.075
# CH ROCHER               12.985
# BANANITA DOLCA          12.850
# CEREZA                  12.840
# FRUTILLA                12.660
# BANANA SPLIT            12.655
# CHOCOLATE               12.630
# MASC FRUTOSROJOS        12.540
# CHOCOLATE SHOT          12.395
# TRAMONTANA              12.375
# MOUSSE DE LIMON         12.115
# DL con NUEZ             11.395
# ...

# %%
mes = agrupar_mensual(df)
mes.reset_index(inplace=True)

# %%
mes
# Out:
#         Fecha  AMERICANA  AMERICANA LIGTH   ANANA  BANANA SPLIT  \
# 0  2021-10-31     25.820            6.635   9.805        24.500
# 1  2021-11-30     73.490           28.010  75.740        79.875
# 2  2021-12-31     33.710           22.450  49.320        23.265
# 3  2022-01-31     20.235            6.690  22.240        26.960
# 4  2022-02-28     30.695            9.465  24.910        27.945
# 5  2022-03-31     33.890            8.865  19.385        36.850
# 6  2022-04-30     23.630           11.235   9.565        18.715
# 7  2022-05-31     22.010           11.015  33.990        33.455
# 8  2022-06-30     30.700           12.710  18.795        22.755
# 9  2022-07-31     32.740            7.525  23.945        29.940
# 10 2022-08-31     17.675            3.255  15.025        32.500
# 11 2022-09-30     26.740           30.880  16.865        27.020
# 12 2022-10-31     33.715           30.220  33.530        38.825
# 13 2022-11-30     14.430           16.530  26.380        23.200
# ...

# %%
m = venta_sort(mes, '2023-02-28')

# %%
m
# Out:
# CH CHUII                17.245
# DL CHUII                16.430
# CH ROCHER               14.730
# FRUTOS DEL BOSQUE       14.420
# KINDER                  14.395
# LIMON                   13.730
# DL                      12.410
# VAINILLA                12.325
# TRAMONTANA              12.250
# CH CON ALMENDRAS        11.920
# AMERICANA               11.145
# CH AMARGO               10.210
# DL con NUEZ              9.365
# DL GRANIZADO             9.305
# MANTECOL                 9.240
# FLAN C DL                8.970
# CHOCOLATE                8.890
# CHOCOTORTA               8.665
# GRANIZADO                8.655
# PISTACHO                 8.430
# CHOCOLATE SHOT           8.410
# COOKIES                  8.215
# SAMBAYON                 8.140
# DL CON BROWNIES          8.015
# MENTA GRANIZADA          7.620
# MANDARINA                7.420
# VAINILLA NUTTY           6.970
# DURAZNO                  6.870
# FRAMBUESA                6.840
# BANANA SPLIT             6.755
# ...
